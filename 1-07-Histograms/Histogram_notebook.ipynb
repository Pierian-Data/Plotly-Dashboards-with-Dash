# %%
import plotly.offline as pyo
import plotly.graph_objs as go
import pandas as pd

# %%
df = pd.read_csv('C:/Users/20194136/Documents/Courses/Plotly-Dashboards-with-Dash/Data/mpg.csv')

# %%
data = [go.Histogram(x=df['mpg'], xbins=dict(start=0,end=50,size=2))]
layout = go.Layout(title='Histogram')

fig = go.Figure(data=data, layout=layout)

pyo.plot(fig)

# %% [markdown]
# ## Exercise

# %%
#######
# Objective: Create a histogram that plots the 'length' field
# from the Abalone dataset (../data/abalone.csv).
# Set the range from 0 to 1, with a bin size of 0.02
######

# Perform imports here:
import numpy as np



# create a DataFrame from the .csv file:
df = pd.read_csv('C:/Users/20194136/Documents/Courses/Plotly-Dashboards-with-Dash/Data/abalone.csv')
print(df)
# create a data variable:

data = [go.Histogram(x=df['length'], xbins=dict(start=0, end=1, size=0.02))]



# add a layout
layout = go.Layout(title='Lenght of players')
fig=go.Figure(data=data, layout=layout)



# create a fig from data & layout, and plot the fig
pyo.plot(fig)
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# 5      I   0.425     0.300   0.095        0.3515          0.1410
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 10     F   0.525     0.380   0.140        0.6065          0.1940
# 11     M   0.430     0.350   0.110        0.4060          0.1675
# 12     M   0.490     0.380   0.135        0.5415          0.2175
# ...
